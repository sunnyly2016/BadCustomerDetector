# %%
#!pip install BadCustomerDetector

# %%
import BadCustomerDetector as bcd
import pandas as pd
# Out:
# C:\Users\LongY\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv('./unique_consumers.csv')

# %%
detector = bcd.BadCustomerDetection()

# %%
kmeans_sel, scaler, detector_list, outliers = detector.bad_customer_detector(df, True, False, 3, 0.05, 'Voting')

# %%
outliers.head()
# Out:
#                             consumer_id  unique_offer_clicked  \
# 0  1284b75c-ecae-4015-8e3d-359c0347ede8                     3
# 1  128af162-d2c3-4fe4-986c-359c8bdc6c04                     3
# 2  12aada5e-36eb-4e9e-8d62-359c076c1b40                     3
# 3  12c2e02f-bc79-4048-83ba-359cd3280dcf                     3
# 4  12fabdf0-0582-489e-a6d3-35509ab8ae6f                     4
#
#    total_offer_clicks  unique_offer_rides  total_offer_rides  \
# 0                   3                   8                 52
# 1                   8                   5                 58
# 2                   4                   9                183
# 3                   7                   4                 56
# 4                   6                   7                 83
#
#    total_offers_claimed  Cluster      CBLOF  CBLOF_Decision            FB  \
# 0                     1        2  10.061674               0  9.914452e-01
# ...
